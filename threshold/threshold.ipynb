# %%
import joblib

# %%
arr = {
        "ds" : ["D:\\app\\hn_ds\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_5_1.pkl",
            "D:\\app\\hn_ds\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_6_1.pkl",
            'D:\\app\\hn_ds\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_5_1.pkl',
            'D:\\app\\hn_ds\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_6_1.pkl'
            ],
        "gy" : ['D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_1\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_1\\Y_threshold_Att_GRU_Set_base_1_2.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_1\\Y_threshold_Att_GRU_Evaporation_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_1\\Y_threshold_Att_GRU_Evaporation_1_2.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_2\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_2\\Y_threshold_Att_GRU_Set_base_1_2.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_2\\Y_threshold_Att_GRU_Evaporation_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_2\\Y_threshold_Att_GRU_Evaporation_1_2.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_3\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_3\\Y_threshold_Att_GRU_Evaporation_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_4\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_gy\\src\\aos_g\\Model\\pre\\mdl_4\\Y_threshold_Att_GRU_Evaporation_1_1.pkl'
            ],
        "hj" : [
            'D:\\app\\hn_hj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_hj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_1_1.pkl',
            ],
        "is" : [
            'D:\\app\\hn_is\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_is\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_1_1.pkl'
        ],
        "pj" : [
            'D:\\app\\hn_pj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hn_pj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_2.pkl'
        ],
        "so" : [
            'D:\\app\\hn_so\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl'
        ],
        "wb" : [
            'D:\\app\\hn_wb\\src\\aos_g\\Model\\pre\Y_threshold_Att_GRU_Set_base_3_3.pkl',
            'D:\\app\\hn_wb\\src\\aos_g\\Model\\pre\Y_threshold_Att_GRU_Set_base_4_1.pkl',
            'D:\\app\\hn_wb\\src\\aos_g\\Model\\pre\Y_threshold_Att_GRU_Evaporation_3_3.pkl'
        ],
        "bw" : [
            'D:\\app\\hs_bw\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_2_1.pkl',
            'D:\\app\\hs_bw\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_2_1.pkl'
        ],
        "cu" : [
            'D:\\app\\hs_cu\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl'
        ],
        "sh" : [
            'D:\\app\\hs_sh\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\hs_sh\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_2_1.pkl',
            'D:\\app\\hs_sh\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_1_1.pkl',
        ],
        "sj" : [
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_5_1.pkl',
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_5_2.pkl',
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_6_1.pkl',
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_5_1.pkl',
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_5_2.pkl',
            'D:\\app\\hs_sj\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_6_1.pkl',
        ],
        "sn" : [
            'D:\\app\\hs_sn\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_3_1.pkl',
            'D:\\app\\hs_sn\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_4_1.pkl',
            'D:\\app\\hs_sn\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_3_1.pkl',
            'D:\\app\\hs_sn\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_4_1.pkl'
        ],
        "by" : [

        ],
        "dh" : [
            'D:\\app\\ys_dh\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\ys_dh\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_1_1.pkl'
        ],
        "dj" : [

        ],
        "hs" : [
            'D:\\app\\ys_hs\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\ys_hs\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_2_1.pkl'
        ],
        "pl" : [
            'D:\\app\\ys_pl\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Set_base_1_1.pkl',
            'D:\\app\\ys_pl\\src\\aos_g\\Model\\pre\\Y_threshold_Att_GRU_Evaporation_1_1.pkl'
        ]

}
#print(arr)

# %%
f = open("result.txt", "w+")

for area in arr:
    #print(area)
    f.write('\n')
    f.write(f'{area}\n')
    for fileLocation in arr[area]:
        #fileLocation.replace("\\", "\\\\")
        y_thod_base = joblib.load(fileLocation)
        lower_threshold_1 = y_thod_base['lower_threshold'].iloc[0]
        upper_threshold_1 = y_thod_base['upper_threshold'].iloc[0]
        #print(fileLocation)
        #print(f'lower_threshold_1 : {lower_threshold_1}')
        #print(f'upper_threshold_1 : {upper_threshold_1}')
        f.write(f'{fileLocation}\n')
        f.write(f'lower_threshold_1 : {lower_threshold_1}\n')
        f.write(f'upper_threshold_1 : {upper_threshold_1}\n')

f.close()
